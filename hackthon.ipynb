# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler,MinMaxScaler

# %%
df = pd.read_csv(r"C:\Users\shakti\Downloads\sme_business_dataset_final.csv")
df
# Out:
#            Date Business_Type  Daily_Sales  Expenses  Customer_Count  Profit  \
# 0    01-01-2025       Service         4327      6878              75   -2551
# 1    02-01-2025     Wholesale        10004      7303              33    2701
# 2    03-01-2025        Retail         4931      1851              47    3080
# 3    04-01-2025       Service         9777      2687              97    7090
# 4    05-01-2025       Service         2197      7833             149   -5636
# ..          ...           ...          ...       ...             ...     ...
# 346  27-12-2025     Wholesale        11827      5777             173    6050
# 347  28-12-2025        Retail         9421      4900             188    4521
# 348  29-12-2025        Retail        11949      7677              54    4272
# 349  30-12-2025       Service         6452      7981              82   -1529
# 350  31-12-2025          Food        12262      7376              44    4886
#
#      Inventory Payment_Mode
# 0          152          UPI
# 1          485          UPI
# 2          398          UPI
# 3          320         Card
# 4          156         Cash
# ..         ...          ...
# 346        401         Card
# 347        248         Cash
# 348        357         Cash
# 349        466  Net Banking
# 350        473         Card
#
# [351 rows x 8 columns]

# %%
df.head()
# Out:
#          Date Business_Type  Daily_Sales  Expenses  Customer_Count  Profit  \
# 0  01-01-2025       Service         4327      6878              75   -2551
# 1  02-01-2025     Wholesale        10004      7303              33    2701
# 2  03-01-2025        Retail         4931      1851              47    3080
# 3  04-01-2025       Service         9777      2687              97    7090
# 4  05-01-2025       Service         2197      7833             149   -5636
#
#    Inventory Payment_Mode
# 0        152          UPI
# 1        485          UPI
# 2        398          UPI
# 3        320         Card
# 4        156         Cash

# %%
df.tail()
# Out:
#            Date Business_Type  Daily_Sales  Expenses  Customer_Count  Profit  \
# 346  27-12-2025     Wholesale        11827      5777             173    6050
# 347  28-12-2025        Retail         9421      4900             188    4521
# 348  29-12-2025        Retail        11949      7677              54    4272
# 349  30-12-2025       Service         6452      7981              82   -1529
# 350  31-12-2025          Food        12262      7376              44    4886
#
#      Inventory Payment_Mode
# 346        401         Card
# 347        248         Cash
# 348        357         Cash
# 349        466  Net Banking
# 350        473         Card

# %%
df.sample(5)
# Out:
#            Date Business_Type  Daily_Sales  Expenses  Customer_Count  Profit  \
# 29   30-01-2025     Wholesale         3959      1825              44    2134
# 65   07-03-2025          Food        14183      5171              74    9012
# 97   08-04-2025     Wholesale         3218      1953             159    1265
# 54   24-02-2025       Service        12248      5968             169    6280
# 171  21-06-2025        Retail         9806      5964             165    3842
#
#      Inventory Payment_Mode
# 29         363  Net Banking
# 65         141         Cash
# 97         239          UPI
# 54         323          UPI
# 171        280         Card

# %%
df.isnull().sum()
# Out:
# Date              0
# Business_Type     0
# Daily_Sales       0
# Expenses          0
# Customer_Count    0
# Profit            0
# Inventory         0
# Payment_Mode      0
# dtype: int64

# %%
columns_to_drop = ["Unnamed: 7", "Unnamed: 8"]
existing_columns = [col for col in columns_to_drop if col in df.columns]
df = df.drop(columns=existing_columns, axis=1)

# %%
df
# Out:
#            Date Business_Type  Daily_Sales  Expenses  Customer_Count  Profit  \
# 0    01-01-2025       Service         4327      6878              75   -2551
# 1    02-01-2025     Wholesale        10004      7303              33    2701
# 2    03-01-2025        Retail         4931      1851              47    3080
# 3    04-01-2025       Service         9777      2687              97    7090
# 4    05-01-2025       Service         2197      7833             149   -5636
# ..          ...           ...          ...       ...             ...     ...
# 346  27-12-2025     Wholesale        11827      5777             173    6050
# 347  28-12-2025        Retail         9421      4900             188    4521
# 348  29-12-2025        Retail        11949      7677              54    4272
# 349  30-12-2025       Service         6452      7981              82   -1529
# 350  31-12-2025          Food        12262      7376              44    4886
#
#      Inventory Payment_Mode
# 0          152          UPI
# 1          485          UPI
# 2          398          UPI
# 3          320         Card
# 4          156         Cash
# ..         ...          ...
# 346        401         Card
# 347        248         Cash
# 348        357         Cash
# 349        466  Net Banking
# 350        473         Card
#
# [351 rows x 8 columns]

# %%
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Business_Type', y='Profit', palette='magma', ci=None)
plt.title('Average Profit by Business Type', fontsize=16)
plt.xlabel('Business Type', fontsize=12)
plt.ylabel('Average Profit', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Payment_Mode', palette='viridis')
plt.title('Frequency of Payment Modes', fontsize=16)
plt.xlabel('Payment Mode', fontsize=12)
plt.ylabel('Number of Transactions', fontsize=12)
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
plt.figure(figsize=(14, 6))
sns.lineplot(data=df, x='Date', y='Daily_Sales', color='royalblue', linewidth=2)
plt.title('Daily Sales Trend Over 2025', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Daily Sales', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Business Metrics', fontsize=16)
plt.show()

# %%
business_counts = df['Business_Type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(business_counts, 
        labels=business_counts.index, 
        autopct='%1.1f%%', 
        startangle=140, 
        colors=sns.color_palette('pastel'))
plt.title('Percentage Distribution of Business Types', fontsize=16)
plt.show()

# %%
payment_counts = df['Payment_Mode'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(payment_counts, 
        labels=payment_counts.index, 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=sns.color_palette('husl'))
plt.title('Percentage Distribution of Payment Modes', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Business_Type', y='Profit', palette='Set2')
plt.title('Distribution of Profit by Business Type', fontsize=16)
plt.xlabel('Business Type', fontsize=12)
plt.ylabel('Profit', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Business_Type', y='Expenses', palette='coolwarm', errorbar=None)
plt.title('Average Expenses by Business Type', fontsize=16)
plt.show()

# %%
df = df.drop(columns=['Date'])
df
# Out:
#     Business_Type  Daily_Sales  Expenses  Customer_Count  Profit  Inventory  \
# 0         Service         4327      6878              75   -2551        152
# 1       Wholesale        10004      7303              33    2701        485
# 2          Retail         4931      1851              47    3080        398
# 3         Service         9777      2687              97    7090        320
# 4         Service         2197      7833             149   -5636        156
# ..            ...          ...       ...             ...     ...        ...
# 346     Wholesale        11827      5777             173    6050        401
# 347        Retail         9421      4900             188    4521        248
# 348        Retail        11949      7677              54    4272        357
# 349       Service         6452      7981              82   -1529        466
# 350          Food        12262      7376              44    4886        473
#
#     Payment_Mode
# 0            UPI
# 1            UPI
# 2            UPI
# 3           Card
# 4           Cash
# ..           ...
# 346         Card
# 347         Cash
# 348         Cash
# 349  Net Banking
# 350         Card
#
# [351 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Business_Type', 'Daily_Sales', 'Expenses', 'Customer_Count', 'Profit',
#        'Inventory', 'Payment_Mode'],
#       dtype='object')

# %%
x = df[['Daily_Sales', 'Inventory', 'Payment_Mode', 'Business_Type', 'Expenses', 'Customer_Count']]

# %%
x= df.drop('Profit',axis=1)
y= df['Profit']

# %%
x= pd.get_dummies(x)
x
# Out:
#      Daily_Sales  Expenses  Customer_Count  Inventory  Business_Type_Food  \
# 0           4327      6878              75        152               False
# 1          10004      7303              33        485               False
# 2           4931      1851              47        398               False
# 3           9777      2687              97        320               False
# 4           2197      7833             149        156               False
# ..           ...       ...             ...        ...                 ...
# 346        11827      5777             173        401               False
# 347         9421      4900             188        248               False
# 348        11949      7677              54        357               False
# 349         6452      7981              82        466               False
# 350        12262      7376              44        473                True
#
#      Business_Type_Retail  Business_Type_Service  Business_Type_Wholesale  \
# 0                   False                   True                    False
# 1                   False                  False                     True
# 2                    True                  False                    False
# 3                   False                   True                    False
# 4                   False                   True                    False
# ..                    ...                    ...                      ...
# 346                 False                  False                     True
# 347                  True                  False                    False
# 348                  True                  False                    False
# 349                 False                   True                    False
# 350                 False                  False                    False
#
#      Payment_Mode_Card  Payment_Mode_Cash  Payment_Mode_Net Banking  \
# 0                False              False                     False
# 1                False              False                     False
# 2                False              False                     False
# 3                 True              False                     False
# 4                False               True                     False
# ..                 ...                ...                       ...
# 346               True              False                     False
# 347              False               True                     False
# 348              False               True                     False
# 349              False              False                      True
# 350               True              False                     False
#
#      Payment_Mode_UPI
# 0                True
# 1                True
# 2                True
# 3               False
# 4               False
# ..                ...
# 346             False
# 347             False
# 348             False
# 349             False
# 350             False
#
# [351 rows x 12 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.8 , random_state=42) # test_sixe=0.2

# %%
LR =LinearRegression()
LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = LR.predict(x_test)

# %%
r2= r2_score(y_test, y_predict)
r2*100
# Out:
# 100.0

# %%
mae= mean_absolute_error( y_test, y_predict)
mae
# Out:
# 2.0199428983918115e-12

# %%
mse= mean_squared_error(y_test, y_predict)
mse
# Out:
# 6.167782629302591e-24

# %%
rmse = root_mean_squared_error(y_test, y_predict)
rmse
# Out:
# 2.4835020896513438e-12

# %%
rmse = root_mean_squared_error(y_test, y_predict)
rmse
# Out:
# 2.4835020896513438e-12

# %%
x
# Out:
#      Daily_Sales  Expenses  Customer_Count  Inventory  Business_Type_Food  \
# 0           4327      6878              75        152               False
# 1          10004      7303              33        485               False
# 2           4931      1851              47        398               False
# 3           9777      2687              97        320               False
# 4           2197      7833             149        156               False
# ..           ...       ...             ...        ...                 ...
# 346        11827      5777             173        401               False
# 347         9421      4900             188        248               False
# 348        11949      7677              54        357               False
# 349         6452      7981              82        466               False
# 350        12262      7376              44        473                True
#
#      Business_Type_Retail  Business_Type_Service  Business_Type_Wholesale  \
# 0                   False                   True                    False
# 1                   False                  False                     True
# 2                    True                  False                    False
# 3                   False                   True                    False
# 4                   False                   True                    False
# ..                    ...                    ...                      ...
# 346                 False                  False                     True
# 347                  True                  False                    False
# 348                  True                  False                    False
# 349                 False                   True                    False
# 350                 False                  False                    False
#
#      Payment_Mode_Card  Payment_Mode_Cash  Payment_Mode_Net Banking  \
# 0                False              False                     False
# 1                False              False                     False
# 2                False              False                     False
# 3                 True              False                     False
# 4                False               True                     False
# ..                 ...                ...                       ...
# 346               True              False                     False
# 347              False               True                     False
# 348              False               True                     False
# 349              False              False                      True
# 350               True              False                     False
#
#      Payment_Mode_UPI
# 0                True
# 1                True
# 2                True
# 3               False
# 4               False
# ..                ...
# 346             False
# 347             False
# 348             False
# 349             False
# 350             False
#
# [351 rows x 12 columns]

# %%
cake_maker = pd.DataFrame([{
    'Daily_Sales' :40000,
    'Expenses': 25000,
    'Customer_Count': 85,
    'Inventory' : 456,
    'Business_Type_Food' : 1,
    'Business_Type_Retail': 0,
    'Business_Type_Service' : 0,
    'Business_Type_Wholesale' : 0,	
    'Payment_Mode_Card' :0,
    'Payment_Mode_Cash' : 1,
    'Payment_Mode_Net Banking' : 0,
    'Payment_Mode_UPI' :1
}])

# %%
LR.predict(cake_maker)
# Out:
# array([15000.])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_predict, color='blue', alpha=0.5, label='Actual vs Predicted')
plt.title('Linear Regression: Actual Sales vs Predicted Sales', fontsize=16)
plt.xlabel('Actual Daily Sales', fontsize=12)
plt.ylabel('Predicted Daily Sales', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
